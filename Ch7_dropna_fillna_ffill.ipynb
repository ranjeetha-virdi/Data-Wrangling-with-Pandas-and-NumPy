# %%
#dropna() ,fillna()

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %%
data=pd.Series([1,NA,3.5,NA,7])

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
df=pd.read_csv("brittleness-index.csv")

# %%
df.head()
# Out:
#    TK104  TK105  TK107
# 0  254.0  263.0    338
# 1  440.0    NaN    470
# 2  501.0    NaN    558
# 3  368.0  451.0    426
# 4  697.0  709.0    733

# %%
cleaned=df.dropna()

# %%
cleaned.head()
# Out:
#    TK104  TK105  TK107
# 0  254.0  263.0    338
# 3  368.0  451.0    426
# 4  697.0  709.0    733
# 5  476.0  542.0    539
# 6  188.0  223.0    240

# %%
cleaned=df.dropna(how='all')

# %%
cleaned.head()
# Out:
#    TK104  TK105  TK107
# 0  254.0  263.0    338
# 1  440.0    NaN    470
# 2  501.0    NaN    558
# 3  368.0  451.0    426
# 4  697.0  709.0    733

# %%
df_test=pd.read_csv("test.csv")
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test.dropna(axis=1,how="all")
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_test[df_test.notnull()]
df_test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_test.dropna(how="all",thresh=75)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1451  2912          20       RL         80.0    13384   Pave   NaN      Reg
# 1452  2913         160       RM         21.0     1533   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_test.fillna({"Alley":0.5,"PoolArea":0})
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   0.5      Reg
# 1     1462          20       RL         81.0    14267   Pave   0.5      IR1
# 2     1463          60       RL         74.0    13830   Pave   0.5      IR1
# 3     1464          60       RL         78.0     9978   Pave   0.5      IR1
# 4     1465         120       RL         43.0     5005   Pave   0.5      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   0.5      Reg
# 1455  2916         160       RM         21.0     1894   Pave   0.5      Reg
# 1456  2917          20       RL        160.0    20000   Pave   0.5      Reg
# 1457  2918          85       RL         62.0    10441   Pave   0.5      Reg
# 1458  2919          60       RL         74.0     9627   Pave   0.5      Reg
#
# ...

# %%
df_t=pd.read_csv("test.csv")
df_t.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
_=df_t.fillna(0,inplace=True)

# %%
df_t
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave     0      Reg
# 1     1462          20       RL         81.0    14267   Pave     0      IR1
# 2     1463          60       RL         74.0    13830   Pave     0      IR1
# 3     1464          60       RL         78.0     9978   Pave     0      IR1
# 4     1465         120       RL         43.0     5005   Pave     0      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave     0      Reg
# 1455  2916         160       RM         21.0     1894   Pave     0      Reg
# 1456  2917          20       RL        160.0    20000   Pave     0      Reg
# 1457  2918          85       RL         62.0    10441   Pave     0      Reg
# 1458  2919          60       RL         74.0     9627   Pave     0      Reg
#
# ...

# %%
df=pd.DataFrame(np.random.randn(6,3))

# %%
df.iloc[2:,1]=NA

# %%
df.iloc[4:,2]=NA

# %%
df
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978       NaN  0.351727
# 3  0.752695       NaN  0.143566
# 4  1.665614       NaN       NaN
# 5  0.405027       NaN       NaN

# %%
df.fillna(method="ffill")
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978  1.580977  0.351727
# 3  0.752695  1.580977  0.143566
# 4  1.665614  1.580977  0.143566
# 5  0.405027  1.580977  0.143566

# %%
df.fillna(method="ffill",limit=2)
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978  1.580977  0.351727
# 3  0.752695  1.580977  0.143566
# 4  1.665614       NaN  0.143566
# 5  0.405027       NaN  0.143566

# %%
df.fillna(df.mean())
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978  0.352603  0.351727
# 3  0.752695  0.352603  0.143566
# 4  1.665614  0.352603 -0.919689
# 5  0.405027  0.352603 -0.919689

# %%
df
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978       NaN  0.351727
# 3  0.752695       NaN  0.143566
# 4  1.665614       NaN       NaN
# 5  0.405027       NaN       NaN

# %%
cols=[0,1,2]

# %%
df.loc[:,cols]=df.loc[:,cols].fillna(method="ffill",limit=2)

# %%
df
# Out:
#           0         1         2
# 0 -0.758538 -0.875770 -0.991809
# 1  0.224448  1.580977 -3.182240
# 2  1.975978  1.580977  0.351727
# 3  0.752695  1.580977  0.143566
# 4  1.665614       NaN  0.143566
# 5  0.405027       NaN  0.143566
