# %%
import requests
import pandas as pd

url="https://api.github.com/repos/pandas-dev/pandas/issues"
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data=resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47967',
#   'id': 1328903804,
#   'node_id': 'PR_kwDOAA0YD848qh5m',
#   'number': 47967,
#   'title': 'CI: fix mypy typing errors (pin numpy) on branch 1.4.x',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/96',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/96',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/96/labels',
#    'id': 8104401,
#    'node_id': 'MI_kwDOAA0YD84Ae6nR',
#    'number': 96,
#    'title': '1.4.4',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 36,
#    'closed_issues': 40,
#    'state': 'open',
#    'created_at': '2022-06-21T19:44:05Z',
#    'updated_at': '2022-08-04T16:33:11Z',
#    'due_on': '2022-07-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-08-04T16:33:11Z',
#   'updated_at': '2022-08-04T16:33:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47967',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47967',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47967.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47967.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #47569 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\ncc @phofl @twoertwein\r\n\r\nI have checked pyright with `pre-commit run -a --hook-stage manual pyright` whereas on ci we are installing pyright but hopefully the versions are the same.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47967/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47966',
#   'id': 1328759498,
#   'node_id': 'I_kwDOAA0YD85PM0LK',
#   'number': 47966,
#   'title': 'BUG: DataFrame apply is swallowing exceptions',
#   'user': {'login': 'emsi',
#    'id': 433383,
#    'node_id': 'MDQ6VXNlcjQzMzM4Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/433383?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emsi',
#    'html_url': 'https://github.com/emsi',
#    'followers_url': 'https://api.github.com/users/emsi/followers',
#    'following_url': 'https://api.github.com/users/emsi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/emsi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/emsi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/emsi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/emsi/orgs',
#    'repos_url': 'https://api.github.com/users/emsi/repos',
#    'events_url': 'https://api.github.com/users/emsi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/emsi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-04T14:53:42Z',
#   'updated_at': '2022-08-04T15:03:37Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ndf = pd.DataFrame(columns=["a", "b"])\r\ndf.apply(lambda x: 7/0, axis=1)\r\n\r\nOut[5]: \r\nEmpty DataFrame\r\nColumns: [a, b]\r\nIndex: []\r\nIn [6]: df.apply(lambda x: undefined, axis=1)\r\nOut[6]: \r\nEmpty DataFrame\r\nColumns: [a, b]\r\nIndex: []\r\n```\r\n\r\nThe same seems to be true for any exception:\r\n```\r\ndef e():\r\n    raise Exception\r\ndf.apply(lambda x: e(), axis=1)\r\nOut[9]: \r\nEmpty DataFrame\r\nColumns: [a, b]\r\nIndex: []\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nDataFrame `apply()` is quietly swallowing exceptions. It returns the DataFrame itself rather than propagating the error.\r\n\r\nPlease note that in previous versions of pandas (e.g. 0.24) this behavior was documented when `reduce` was `None` (default). However there is no mention of such behavior in documentation of current version.\r\n\r\n### Expected Behavior\r\n\r\nEn exception should be thrown or this behavior should be documented.  \r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : e8093ba372f9adfe79439d90fe74b0b5b6dea9d6\r\npython           : 3.9.12.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-121-generic\r\nVersion          : #137-Ubuntu SMP Wed Jun 15 13:33:07 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\npandas           : 1.4.3\r\nnumpy            : 1.22.3\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 58.1.0\r\npip              : 22.0.4\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.1\r\nIPython          : 8.2.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2022.3.0\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : 2.8.1\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : 3.7.0\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47966/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47964',
#   'id': 1328710718,
#   'node_id': 'I_kwDOAA0YD85PMoQ-',
#   'number': 47964,
#   'title': "STYLE check pandas doesn't use external package when that package is vendored",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-04T14:19:13Z',
#   'updated_at': '2022-08-04T14:19:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'xref https://github.com/pandas-dev/pandas/pull/47939#issue-1326760809',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47964/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47963',
#   'id': 1328495790,
#   'node_id': 'I_kwDOAA0YD85PLzyu',
#   'number': 47963,
#   'title': 'BUG: `pd.Grouper` creates empty groups (and in doing so is inconsistent with `groupby`) with `pd.DatetimeIndex`',
#   'user': {'login': 'bollard',
#    'id': 358225,
#    'node_id': 'MDQ6VXNlcjM1ODIyNQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/358225?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bollard',
#    'html_url': 'https://github.com/bollard',
#    'followers_url': 'https://api.github.com/users/bollard/followers',
#    'following_url': 'https://api.github.com/users/bollard/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bollard/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bollard/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bollard/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bollard/orgs',
#    'repos_url': 'https://api.github.com/users/bollard/repos',
#    'events_url': 'https://api.github.com/users/bollard/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bollard/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-04T11:42:55Z',
#   'updated_at': '2022-08-04T11:42:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\n\r\n# note, does not include today\r\nday_offset = [-2, -1, 1, 2]\r\ntimestamps = [pd.Timestamp.now() + pd.Timedelta(days=d) for d in day_offset]\r\n\r\ndf_ts = pd.DataFrame(\r\n    data={"offset": day_offset},\r\n    index=pd.Index(timestamps, name="timestamp")\r\n)\r\n\r\nprint("\\n===============")\r\nprint("{}\\n".format(df_ts))\r\n\r\n# want to group by the day\r\ngrouper = pd.Grouper(level="timestamp", freq="D")\r\ngrouped = df_ts.groupby(grouper)\r\nprint("[Grouper] Groups: {}, Indicies: {}\\n".format(len(grouped.groups), len(grouped.indices)))\r\n\r\nfor key, df_group in grouped:\r\n    print("{}: {}".format(key, len(df_group)))\r\n    \r\n    if key.date() == pd.Timestamp.now().date():\r\n        print("...?") # unexpected!\r\n\r\ndf_date = pd.DataFrame(\r\n    data={"offset": day_offset},\r\n    index=pd.Index(df_ts.index.date, name=\'date\')\r\n)\r\n\r\nprint("\\n===============")\r\nprint("{}\\n".format(df_date))\r\n\r\ngrouped = df_date.groupby(\'date\')\r\nprint("[Groupby] Groups: {}, Indicies: {}\\n".format(len(grouped.groups), len(grouped.indices)))\r\n\r\nfor key, df_group in grouped:\r\n    print("{}: {}".format(key, len(df_group)))\n```\n\n\n### Issue Description\n\nHello,\r\n\r\nIn the example above, I am trying to group datetimes to dates, using the `pd.Grouper(..., freq="D")`, however this creates a key for a date which doesn\'t exist in the data. This behaviour is different to using `groupby` on dates directly (which does not create a missing key). Also note this creates a mismatch in the size of the `.groups` and the `.indices` (as the latter does _not_ include the empty reference)\r\n\r\nThis creates unexpected behaviour when you try to loop over the groups later (and have more groups than you\'d expect).\r\n\r\nThis is also not particularly easy to handle on the user end (if we do not wish to reconstruct the groupby object). Instead I have resorted to looping over the `grouped.indices.keys()` and the using `get_group` to avoid the empty group.\n\n### Expected Behavior\n\nThe empty group would not be created with the `pd.Grouper`\n\n### Installed Versions\n\n<details>\r\n\r\ncommit           : e8093ba372f9adfe79439d90fe74b0b5b6dea9d6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 165 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.4.3\r\nnumpy            : 1.23.1\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 61.2.0\r\npip              : 22.1.2\r\nCython           : None\r\npytest           : 6.2.5\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.4.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.5.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy           ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47963/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47962',
#   'id': 1328492289,
#   'node_id': 'PR_kwDOAA0YD848pJF5',
#   'number': 47962,
#   'title': "BUG: read_csv with engine pyarrow doesn't handle missing values",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T11:39:47Z',
#   'updated_at': '2022-08-04T14:11:58Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47962',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47962',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47962.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47962.patch',
#    'merged_at': None},
#   'body': '- [x] closes #47950 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47962/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47961',
#   'id': 1328449752,
#   'node_id': 'I_kwDOAA0YD85PLojY',
#   'number': 47961,
#   'title': "BUG: read_csv with engine pyarrow doesn't handle parsing multiple date columns",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T11:00:14Z',
#   'updated_at': '2022-08-04T11:11:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport io\r\n\r\ndata = """idx,date,time\r\n2,2000-01-01, 00:00:00\r\n3,2000-01-01, 00:01:00\r\n4,2000-01-01, 00:02:00\r\n"""\r\n\r\ndf = pd.read_csv(io.StringIO(data), parse_dates={\'date2\': [\'date\', \'time\']})\r\nprint(df)\r\ndf = pd.read_csv(io.StringIO(data), parse_dates={\'date2\': [\'date\', \'time\']}, engine=\'pyarrow\')\n```\n\n\n### Issue Description\n\nWithout `, engine=\'pyarrow\'`, it works fine. With it, we get\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/home/megorelli/pandas-dev/t.py", line 10, in <module>\r\n    df = pd.read_csv(io.StringIO(data), parse_dates={\'date2\': [\'date\', \'time\']}, engine=\'pyarrow\')\r\n  File "/home/megorelli/pandas-dev/pandas/util/_decorators.py", line 317, in wrapper\r\n    return func(*args, **kwargs)\r\n  File "/home/megorelli/pandas-dev/pandas/io/parsers/readers.py", line 943, in read_csv\r\n    return _read(filepath_or_buffer, kwds)\r\n  File "/home/megorelli/pandas-dev/pandas/io/parsers/readers.py", line 605, in _read\r\n    return parser.read(nrows)\r\n  File "/home/megorelli/pandas-dev/pandas/io/parsers/readers.py", line 1748, in read\r\n    df = self._engine.read()  # type: ignore[attr-defined]\r\n  File "/home/megorelli/pandas-dev/pandas/io/parsers/arrow_parser_wrapper.py", line 152, in read\r\n    return self._finalize_output(frame)\r\n  File "/home/megorelli/pandas-dev/pandas/io/parsers/arrow_parser_wrapper.py", line 108, in _finalize_output\r\n    frame.columns, frame = self._do_date_conversions(frame.columns, frame)\r\n  File "/home/megorelli/pandas-dev/pandas/core/generic.py", line 5852, in __setattr__\r\n    return object.__setattr__(self, name, value)\r\n  File "pandas/_libs/properties.pyx", line 69, in pandas._libs.properties.AxisProperty.__set__\r\n    obj._set_axis(self.axis, value)\r\n  File "/home/megorelli/pandas-dev/pandas/core/generic.py", line 771, in _set_axis\r\n    self._mgr.set_axis(axis, labels)\r\n  File "/home/megorelli/pandas-dev/pandas/core/internals/managers.py", line 218, in set_axis\r\n    self._validate_set_axis(axis, new_labels)\r\n  File "/home/megorelli/pandas-dev/pandas/core/internals/base.py", line 70, in _validate_set_axis\r\n    raise ValueError(\r\nValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements\r\n```\n\n### Expected Behavior\n\n```\r\n                date2  idx\r\n0 2000-01-01 00:00:00    2\r\n1 2000-01-01 00:01:00    3\r\n2 2000-01-01 00:02:00    4\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n/home/megorelli/pandas-dev/.venv/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 690a77fe19f9229ff02987abbd487a63c2cbe1b8\r\npython           : 3.9.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.114-16025-ge75506b9d98e\r\nVersion          : #1 SMP PREEMPT Sat Jul 16 18:52:19 PDT 2022\r\nmachine          : aarch64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.0.dev0+1231.g690a77fe19.dirty\r\nnumpy            : 1.22.4\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 62.1.0\r\npip              : 22.0.4\r\nCython           : 0.29.30\r\npytest           : 7.1.2\r\nhypothesis       : 6.47.1\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47961/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47960',
#   'id': 1328201471,
#   'node_id': 'I_kwDOAA0YD85PKr7_',
#   'number': 47960,
#   'title': 'WEB: Review donation options for pandas',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 32933285,
#     'node_id': 'MDU6TGFiZWwzMjkzMzI4NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Admin',
#     'name': 'Admin',
#     'color': 'DDDDDD',
#     'default': False,
#     'description': 'Administrative tasks related to the pandas project'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T07:37:52Z',
#   'updated_at': '2022-08-04T13:30:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "In #47931 @logankilpatrick suggested that we add support for GitHub sponsors to pandas. I don't know much about it, but seems like we've got it enabled, but just providing links to our donations page and tidelift. I guess we can set it up to receive donations directly.\r\n\r\nBesides it, we've got now https://opencollective.com/pandas which also handles donations, and I think it's intended to replace the current salsa donations we're currently using in our website.\r\n\r\nAlso, maybe we want to discuss whether out [Contribute](https://pandas.pydata.org/contribute.html) page has the visibility and the options that we want. I think naming the section `Contribute` may sound to much as helping pandas with coding. Renaming it to `Donate` may sound as just giving individual donations. Would it make sense to rename it to something else where it's more clear for visitors of the website that they can contribute code, corporate sponsorship, money... Not sure if something like `Help pandas`, `Get involved`... Probably native English speakers can find something better. Also, would it be worth adding Tidelift to the options in that page? Or anything else?",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47960/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47959',
#   'id': 1328191613,
#   'node_id': 'I_kwDOAA0YD85PKph9',
#   'number': 47959,
#   'title': 'Specify the behaviour for empty input',
#   'user': {'login': 'Th3nn3ss',
#    'id': 25160953,
#    'node_id': 'MDQ6VXNlcjI1MTYwOTUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25160953?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Th3nn3ss',
#    'html_url': 'https://github.com/Th3nn3ss',
#    'followers_url': 'https://api.github.com/users/Th3nn3ss/followers',
#    'following_url': 'https://api.github.com/users/Th3nn3ss/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Th3nn3ss/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Th3nn3ss/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Th3nn3ss/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Th3nn3ss/orgs',
#    'repos_url': 'https://api.github.com/users/Th3nn3ss/repos',
#    'events_url': 'https://api.github.com/users/Th3nn3ss/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Th3nn3ss/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T07:28:48Z',
#   'updated_at': '2022-08-04T15:48:55Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'There isn\'t an issue for empty inputs. \r\n\r\nThere is a need to specify the behaviour for empty input. Note that “empty” input can mean many things, and even combinations of them:\r\n\r\n- zero rows but non-zero columns\r\n- zero columns but non-zero rows\r\n- zero rows and zero columns\r\n- other: e.g., empty list provided to `agg()`\r\n\r\nAs suggested by @shwina in the Pandas Standardisation docs, the idea is to start by writing a bunch of tests across many different Pandas operations and see how many pass across libraries.\r\n\r\nClassic example (quiz: what should this do?)\r\n\r\n>>> df = pd.DataFrame({"a": [], "b": []})\r\n>>> df.groupby(“a”).agg({})\r\n\r\nA starting list of operations where tests are needed would be particularly helpful, I plan to start going through them and adding all the tests.\r\n\r\n- [ ] The above example returns a `ValueError: No objects to concatenate`, is this the expected behaviour? \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47959/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47958',
#   'id': 1328169240,
#   'node_id': 'PR_kwDOAA0YD848oD6r',
#   'number': 47958,
#   'title': 'ENH: Add `dtype` param for `pandas.Series.str.get_dummies`',
#   'user': {'login': 'JeffersonQin',
#    'id': 30655701,
#    'node_id': 'MDQ6VXNlcjMwNjU1NzAx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30655701?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JeffersonQin',
#    'html_url': 'https://github.com/JeffersonQin',
#    'followers_url': 'https://api.github.com/users/JeffersonQin/followers',
#    'following_url': 'https://api.github.com/users/JeffersonQin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JeffersonQin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JeffersonQin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JeffersonQin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JeffersonQin/orgs',
#    'repos_url': 'https://api.github.com/users/JeffersonQin/repos',
#    'events_url': 'https://api.github.com/users/JeffersonQin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JeffersonQin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T07:06:59Z',
#   'updated_at': '2022-08-04T10:22:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47958',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47958',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47958.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47958.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #47872 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47958/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47956',
#   'id': 1328002838,
#   'node_id': 'PR_kwDOAA0YD848ng3Q',
#   'number': 47956,
#   'title': 'Issue46882',
#   'user': {'login': 'Mehgarg',
#    'id': 65103188,
#    'node_id': 'MDQ6VXNlcjY1MTAzMTg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65103188?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mehgarg',
#    'html_url': 'https://github.com/Mehgarg',
#    'followers_url': 'https://api.github.com/users/Mehgarg/followers',
#    'following_url': 'https://api.github.com/users/Mehgarg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Mehgarg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Mehgarg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Mehgarg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Mehgarg/orgs',
#    'repos_url': 'https://api.github.com/users/Mehgarg/repos',
#    'events_url': 'https://api.github.com/users/Mehgarg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Mehgarg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-04T03:03:40Z',
#   'updated_at': '2022-08-04T08:08:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47956',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47956',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47956.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47956.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #46882 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47956/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47955',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47955/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47955/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47955/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47955',
#   'id': 1327997065,
#   'node_id': 'I_kwDOAA0YD85PJ6CJ',
#   'number': 47955,
#   'title': 'PERF: .clip with datetime64[ns, UTC] Series regressed',
#   'user': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
# ...
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-08-02T17:37:08Z',
#   'updated_at': '2022-08-04T03:17:20Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47932',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47932',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47932.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47932.patch',
#    'merged_at': None},
#   'body': 'This also opens the option of deprecating `inplace` here.\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47932/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47932/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47931',
#   'id': 1326056096,
#   'node_id': 'PR_kwDOAA0YD848hCRM',
#   'number': 47931,
#   'title': 'Update config.yml to add Donate page to the nav bar',
#   'user': {'login': 'logankilpatrick',
#    'id': 35577566,
#    'node_id': 'MDQ6VXNlcjM1NTc3NTY2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35577566?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/logankilpatrick',
#    'html_url': 'https://github.com/logankilpatrick',
#    'followers_url': 'https://api.github.com/users/logankilpatrick/followers',
#    'following_url': 'https://api.github.com/users/logankilpatrick/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/logankilpatrick/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/logankilpatrick/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/logankilpatrick/subscriptions',
#    'organizations_url': 'https://api.github.com/users/logankilpatrick/orgs',
#    'repos_url': 'https://api.github.com/users/logankilpatrick/repos',
#    'events_url': 'https://api.github.com/users/logankilpatrick/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/logankilpatrick/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 32933285,
#     'node_id': 'MDU6TGFiZWwzMjkzMzI4NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Admin',
#     'name': 'Admin',
#     'color': 'DDDDDD',
#     'default': False,
#     'description': 'Administrative tasks related to the pandas project'},
#    {'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-08-02T15:51:30Z',
#   'updated_at': '2022-08-04T07:40:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47931',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47931',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47931.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47931.patch',
#    'merged_at': None},
#   'body': "It would also be really great to enable GitHub sponsors specifically for the Pandas Org since people might want to sponsor the org directly on GitHub (dev's / org's want to highlight their sponsorship publicly so GitHub sponsors is a great way to do so).\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47931/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47930',
#   'id': 1326036755,
#   'node_id': 'I_kwDOAA0YD85PCbcT',
#   'number': 47930,
#   'title': 'ENH: Add new date_format option to_json matching datetime.isoformat exactly',
#   'user': {'login': 'PMLP-novo',
#    'id': 54025656,
#    'node_id': 'MDQ6VXNlcjU0MDI1NjU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54025656?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PMLP-novo',
#    'html_url': 'https://github.com/PMLP-novo',
#    'followers_url': 'https://api.github.com/users/PMLP-novo/followers',
#    'following_url': 'https://api.github.com/users/PMLP-novo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PMLP-novo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PMLP-novo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PMLP-novo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PMLP-novo/orgs',
#    'repos_url': 'https://api.github.com/users/PMLP-novo/repos',
#    'events_url': 'https://api.github.com/users/PMLP-novo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PMLP-novo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-02T15:36:32Z',
#   'updated_at': '2022-08-02T15:51:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [X] Adding new functionality to pandas\r\n\r\n- [ ] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\nI wish to have the option to serialised datetimes the same way in the same way that the build in datetime.isoformat  serialises them. Such that I don\'t produce datetimes in different formats and my tests can be writen nices. \r\nRight now:\r\npandas datetime produces: "2022-08-02T15:24:54.987Z"\r\ncompared to python datetime:  "2022-08-02T15:24:54.987994"\r\n\r\n### Feature Description\r\n\r\nI wish the following test would pass\r\n```\r\nimport pandas as pd\r\nfrom datetime import datetime\r\ndt = datetime.now()\r\npandas__in_python_iso = pd.DataFrame([{"test":dt}]).to_json(date_format="python-iso", orient="records")\r\npython_iso8601 = [{"test":dt.isoformat()}]\r\nassert pandas__in_python_iso ==python_iso8601\r\n```\r\n\r\n### Alternative Solutions\r\n\r\nthe new date_format option could have other names\r\n\r\n### Additional Context\r\n\r\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47930/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47928',
#   'id': 1325302562,
#   'node_id': 'I_kwDOAA0YD85O_oMi',
#   'number': 47928,
#   'title': 'Potential issue when running "python ./scripts/validate_docstrings.py --errors=PR02"',
#   'user': {'login': 'joshuabello2550',
#    'id': 43732414,
#    'node_id': 'MDQ6VXNlcjQzNzMyNDE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43732414?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joshuabello2550',
#    'html_url': 'https://github.com/joshuabello2550',
#    'followers_url': 'https://api.github.com/users/joshuabello2550/followers',
#    'following_url': 'https://api.github.com/users/joshuabello2550/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joshuabello2550/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joshuabello2550/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joshuabello2550/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joshuabello2550/orgs',
#    'repos_url': 'https://api.github.com/users/joshuabello2550/repos',
#    'events_url': 'https://api.github.com/users/joshuabello2550/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joshuabello2550/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-08-02T05:22:31Z',
#   'updated_at': '2022-08-02T05:22:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "When a user runs the command `python ./scripts/validate_docstrings.py --errors=PR02` in a terminal they are presented with a list of errors with the docstrings for functions, such as what is shown in the errors.txt file (I created). In the errors' list, many errors point to the same line of code, such as `/home/pandas/pandas/core/indexes/extension.py:92`. However, when you look at the line in the file, line 92 ` def method(self, *args, **kwargs)` it seems to just be defining a function within another wrapper function. Are these errors supposed to be at the same location or should the validate doc-strings only check the wrapper function's doc-string and not the inner function?\r\n\r\n![Screenshot 2022-08-01 215851](https://user-images.githubusercontent.com/43732414/182296642-03dba665-39f0-4a0b-ba43-b753e63a2526.png)\r\n![Screenshot 2022-08-01 220408](https://user-images.githubusercontent.com/43732414/182296645-e81212ca-6609-4116-bdd1-c0dbd4311351.png)\r\n![Screenshot 2022-08-01 220440](https://user-images.githubusercontent.com/43732414/182296647-543ce38e-0b23-4194-9bd0-009a65f40f60.png)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47928/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47927',
#   'id': 1325295091,
#   'node_id': 'PR_kwDOAA0YD848ee1r',
#   'number': 47927,
#   'title': 'ENH: Support For Interval __contains__ Other Interval (#46613)',
#   'user': {'login': 'kapiliyer',
#    'id': 90269125,
#    'node_id': 'MDQ6VXNlcjkwMjY5MTI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90269125?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kapiliyer',
#    'html_url': 'https://github.com/kapiliyer',
#    'followers_url': 'https://api.github.com/users/kapiliyer/followers',
#    'following_url': 'https://api.github.com/users/kapiliyer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kapiliyer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kapiliyer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kapiliyer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kapiliyer/orgs',
#    'repos_url': 'https://api.github.com/users/kapiliyer/repos',
#    'events_url': 'https://api.github.com/users/kapiliyer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kapiliyer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-08-02T05:10:12Z',
#   'updated_at': '2022-08-04T14:34:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47927',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47927',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47927.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47927.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46613\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47927/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
data[0]["title"]
# Out:
# 'CI: fix mypy typing errors (pin numpy) on branch 1.4.x'

# %%
issues=pd.DataFrame(data,columns=["number","title","labels","state"])

# %%
issues
# Out:
#     number                                              title  \
# 0    47967  CI: fix mypy typing errors (pin numpy) on bran...
# 1    47966      BUG: DataFrame apply is swallowing exceptions
# 2    47964  STYLE check pandas doesn't use external packag...
# 3    47963  BUG: `pd.Grouper` creates empty groups (and in...
# 4    47962  BUG: read_csv with engine pyarrow doesn't hand...
# 5    47961  BUG: read_csv with engine pyarrow doesn't hand...
# 6    47960            WEB: Review donation options for pandas
# 7    47959              Specify the behaviour for empty input
# 8    47958  ENH: Add `dtype` param for `pandas.Series.str....
# 9    47956                                         Issue46882
# 10   47955  PERF: .clip with datetime64[ns, UTC] Series re...
# 11   47953           BUG: inconsistent behavior of DateOffset
# 12   47952              DEBUG: Debug failing macpython wheels
# 13   47950  BUG: read_csv with engine pyarrow doesn't hand...
# 14   47948      DOC: Plotting / Visualization without Jupyter
# 15   47947  BUG: Propagating precision to interval dtype #...
# 16   47946        Fix bug in pd.merge when joining two Series
# 17   47944  BUG: Ordering of `columns` is not preserved in...
# 18   47942  BUG: Resampler.quantile produce inconsistent r...
# 19   47941  BUG: union of lists of DatetimeIndex generates...
# 20   47937  WARN : extended stack level check to include a...
# 21   47936                         CLN: remove deprecated DEF
# 22   47935    Fix out-of-bounds heap access in internals.pyx.
# 23   47934            ENH: copy kwd for add_suffix/add_prefix
# 24   47933  nightly builds failing since 19 July on MacPyt...
# 25   47932                      ENH: copy keyword to set_axis
# 26   47931  Update config.yml to add Donate page to the na...
# 27   47930  ENH: Add new date_format option to_json matchi...
# 28   47928  Potential issue when running "python ./scripts...
# 29   47927  ENH: Support For Interval __contains__ Other I...
#
#                                                labels state
# 0   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 1   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2   [{'id': 106935113, 'node_id': 'MDU6TGFiZWwxMDY...  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4                                                  []  open
# 5   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6   [{'id': 32933285, 'node_id': 'MDU6TGFiZWwzMjkz...  open
# 7                                                  []  open
# 8                                                  []  open
# 9                                                  []  open
# 10  [{'id': 211840, 'node_id': 'MDU6TGFiZWwyMTE4ND...  open
# 11  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 12                                                 []  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 15                                                 []  open
# 16  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 17  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20                                                 []  open
# 21  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 22  [{'id': 49094459, 'node_id': 'MDU6TGFiZWw0OTA5...  open
# 23                                                 []  open
# 24                                                 []  open
# 25                                                 []  open
# 26  [{'id': 32933285, 'node_id': 'MDU6TGFiZWwzMjkz...  open
# 27  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 28                                                 []  open
# 29                                                 []  open

# %%
import sqlite3

# %%
query="""
      CREATE TABLE test
      (a VARCHAR (20), b VARCHAR(20),c REAL, d INTEGER);"""

# %%
con = sqlite3.connect("mydata.sqlite")
con.execute(query)

# %%
con.commit()

# %%
data = [("Atlanta", "Georgia", 1.25, 6),
       ("Tallahassee","Florida",2.6,3),
       ("Sacramento","California",1.7,5)]

# %%
stmt="INSERT INTO test VALUES(?,?,?,?)"

# %%
con.executemany(stmt,data)

# %%
con.commit()

# %%
cursor=con.execute("select * from test")

# %%
rows=cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows,columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla

# %%
db=sqla.create_engine("sqlite:///mydata.sqlite")
pd.read_sql("select * from test",db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
